# %% [markdown]
# # Chapter 25. General Matplotlib Tips
#
# We will use `mpl` as a shorthand for Matplotlib and `plt` for PyPlot.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Here we will set the classic style, which ensures that the plots we create use the classic Matplotlib style:

# %%
plt.style.use('classic')

# %% [markdown]
# Plotting interactively within a Jupyter notebook can be done with the `%matplotlib` command, with two possible options:
#
# - `%matplotlib inline` will lead to *static* images of your plot embedded in the notebook
# - `%matplotlib notebook` will lead to *interactive* plots embedded within the notebook

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %% [markdown]
# #### MATLAB-style Interface
#
# This interface is *stateful*: it keeps track of the *current* figure and axes, which are where all `plt` commands are applied.

# %%
# create a plot figure
plt.figure()

# create the first of two panels
plt.subplot(2, 1, 1)     # (rows, columns, panel id)
plt.plot(x, np.sin(x))

# create the second panel
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# #### Object-oriented interface
#
# For simpler plot, the choice of which style is largely a matter of preference, but the object-oriented approach can become a necessity as plots become more complicated.

# %%
# create a grid of plots
fig, ax = plt.subplots(2)

# ax is an array of two Axes objects
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));
